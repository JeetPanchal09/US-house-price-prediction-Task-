# %% [markdown]
# #         Given Task :
#
# # Describe and explain all the factors that could influence residential home prices across the United States over the next 10 years, and how.

# %% [markdown]
# ###  > To solve this task I am going to use my machine learning and data science skills.
# ###  > For this  we need some previous year data and some stats which can help us to derive many conlusion with the help of Exploratory Data Analysis(EDA).
# ### > I have downloaded some data from "Kaggle" ,which verified and trusted site by data scientist and contians original data.Other than that some of the data I have downloaded from Wikipedia.

# %% [markdown]
#
#
#
#
#
#
# ###  (A)
#
#
#
# ### One of the major factor which influence not only the house prices but,any prices of a given  product is 'supply and demand'.
#
# ### The housing market is subject to the same economic laws of supply and demand as every other industry. When there are more buyers than sellers, the supply of houses goes down and the demand goes up, making houses harder to buy and more expensive.
#
#
# ### To understand this I have downloaded some data from Wikipedia.The data contains US popualation from 2011-2021.

# %%
## importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
US_population = pd.read_csv("US Population 2011–2021.csv")
US_population
# Out:
#     Year    Population
# 0   2011  31,15,83,481
# 1   2012  31,38,77,662
# 2   2013  31,60,59,947
# 3   2014  31,83,86,329
# 4   2015  32,07,38,994
# 5   2016  32,30,71,755
# 6   2017  32,51,22,128
# 7   2018  32,68,38,199
# 8   2019  32,83,29,953
# 9   2020  33,15,01,080
# 10  2021  33,18,93,745

# %%
plt.plot(US_population['Year'],US_population['Population'])
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Year vs Population')
plt.show()

# %% [markdown]
# ### From above line plot we clearly see that the population is keep increasing through the years and it is only going to increase in upcoming years ,so it is a major factor that will influence house pricing in US in  upcoming years.

# %% [markdown]
# ### (B)
#
# ### The Economy
#
# ### When the economy is going strong and unemployment goes down, housing prices tend to rise. In a strong economy, people feel more secure in their jobs and their ability to take on mortgage debt. They're also more likely to get approved for that mortgage.
#
# ### When the economy falters, however, more people find themselves laid off, having to live on unemployment compensation or accept much lower paying jobs. When this happens, fewer people are able to purchase houses, competition for them goes away and motivated sellers must lower their asking price to get a sale.
#
# ### For this part we are going to look at two datasets which contains GDP growth of US through the years and Unemployment in US through the years respectively.

# %%
GDP = pd.read_csv("GDP.csv")
GDP.head()
# Out:
#          Date      GDP
# 0  01-01-1947  243.164
# 1  01-04-1947  245.968
# 2  01-07-1947  249.585
# 3  01-10-1947  259.745
# 4  01-01-1948  265.742

# %%
## From above we can see the Date is given in quarters.So, we will convert it in years.
import datetime
GDP['Date'] = pd.to_datetime(GDP['Date'])
GDP['year'] = pd.DatetimeIndex(GDP['Date']).year
GDP.head()
# Out:
#         Date      GDP  year
# 0 1947-01-01  243.164  1947
# 1 1947-01-04  245.968  1947
# 2 1947-01-07  249.585  1947
# 3 1947-01-10  259.745  1947
# 4 1948-01-01  265.742  1948

# %%
GDP.drop(columns='Date')
GDP.head()
# Out:
#         Date      GDP  year
# 0 1947-01-01  243.164  1947
# 1 1947-01-04  245.968  1947
# 2 1947-01-07  249.585  1947
# 3 1947-01-10  259.745  1947
# 4 1948-01-01  265.742  1948

# %%
GDP= GDP[['year','GDP']]
GDP=GDP.groupby('year').median().astype('int64')
GDP.head()
# Out:
#       GDP
# year
# 1947  247
# 1948  275
# 1949  272
# 1950  299
# 1951  347

# %%
plt.figure(figsize=(20, 6))
plt.plot(GDP['GDP'],color='red')
plt.xlabel('Year',fontsize = 15)

plt.ylabel('GDP (Billions of Dollars)',fontsize = 15)
plt.tick_params(axis='both', which = 'major', labelsize = 18)
plt.title('GDP, by Year',fontsize = 23)
plt.show()

# %% [markdown]
# ### we have seen two major factors that directly effects House prices in US.Now we will see more factors that will effect house pricing in upcoming years.

# %% [markdown]
# # For this I have downloaded a dataset and with help of these dataset we will analyse and make conclusion on what factor are going to effect house price in US in upcoming years.

# %% [markdown]
# ### We are going to use the USA_Housing dataset.The data contains the following columns:
#
#
# ###   >  'Avg. Area Income': Avg. Income of residents of the city house is located in.
#
#
# ###  >   'Avg. Area House Age': Avg Age of Houses in same city
#
#
# ###  >   'Avg. Area Number of Rooms': Avg Number of Rooms for Houses in same city
#
#
# ###  >   'Avg. Area Number of Bedrooms': Avg Number of Bedrooms for Houses in same city
#
#
# ###  >   'Area Population': Population of city hou se is located in
#
#
# ###  >   'Price': Price that the house sold at
#
#
# ###  >   'Address': Address for the house

# %%
df = pd.read_csv("USA_Housing.csv")
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
# adding state column with help of address column
df['State'] = df['Address'].apply(lambda x: x.split(' ')[-2])

# %%
df.State.value_counts()
# Out:
# AA    177
# AP    170
# AE    167
# OR     91
# GU     91
#      ...
# KS     67
# AK     67
# IL     64
# MD     62
# VI     55
# Name: State, Length: 62, dtype: int64

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address State
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...    NE
# ...

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# ### Question : Does Area income affect price of house?

# %%
df['Avg. Area Income'].describe()
# Out:
# count      5000.000000
# mean      68583.108984
# std       10657.991214
# min       17796.631190
# 25%       61480.562388
# 50%       68804.286404
# 75%       75783.338666
# max      107701.748378
# Name: Avg. Area Income, dtype: float64

# %%
ranges = [0, 20000, 40000, 60000, 80000, np.inf]
label = ['0-20000', '20000-40000', '40000-60000', '60000-80000', '80000+']

pd.cut(df['Avg. Area Income'], bins=ranges, labels=label).head()
# Out:
# 0    60000-80000
# 1    60000-80000
# 2    60000-80000
# 3    60000-80000
# 4    40000-60000
# Name: Avg. Area Income, dtype: category
# Categories (5, object): ['0-20000' < '20000-40000' < '40000-60000' < '60000-80000' < '80000+']

# %%
df.groupby(pd.cut(df['Avg. Area Income'], bins=ranges, labels=label))['Price'].mean().plot()
plt.title('Area income VS House price')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### We clearly see a linear realtionship between Average Area income and price of house.So,it definetly Affect the house of the price.

# %% [markdown]
# ### Question : Does age of house have any affect on it's price?

# %%
df['Avg. Area House Age'].describe()
# Out:
# count    5000.000000
# mean        5.977222
# std         0.991456
# min         2.644304
# 25%         5.322283
# 50%         5.970429
# 75%         6.650808
# max         9.519088
# Name: Avg. Area House Age, dtype: float64

# %%
df.groupby(round(df['Avg. Area House Age']))['Price'].mean().plot()
plt.title('House age VS House price')
plt.xlabel('House age (years)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Ans: Yes it does affect as there is a linear relationship between House age and it's price. But price increase until it's less than 10 years, after that the price decrease drastically and most probably it will continue to decrease. This makes sence as people wants new house as it have less maintenance.

# %% [markdown]
# ###   Question : Does number of rooms and bedrooms have any effect on prices?

# %%
df['Avg. Area Number of Bedrooms'].describe()
# Out:
# count    5000.000000
# mean        3.981330
# std         1.234137
# min         2.000000
# 25%         3.140000
# 50%         4.050000
# 75%         4.490000
# max         6.500000
# Name: Avg. Area Number of Bedrooms, dtype: float64

# %%
display(df.groupby(round(df['Avg. Area Number of Rooms']))['Price'].mean())
# Out:
# Avg. Area Number of Rooms
# 3.0     1.365081e+06
# 4.0     9.020765e+05
# 5.0     1.020620e+06
# 6.0     1.124506e+06
# 7.0     1.234440e+06
# 8.0     1.334549e+06
# 9.0     1.464372e+06
# 10.0    1.591249e+06
# 11.0    2.235295e+06
# Name: Price, dtype: float64

# %%
    df.groupby(round(df['Avg. Area Number of Rooms']))['Price'].mean().plot()
    plt.ylabel('Price')
    plt.show()

# %% [markdown]
# ### Answer : Price will increase gradually with number of Rooms and Bedrooms.

# %% [markdown]
# ## Question : Does City affect prices of houses?

# %%
df.groupby('State')['Price'].mean().sort_values(ascending=False)
# Out:
# State
# AK    1.337328e+06
# TX    1.336076e+06
# UT    1.308736e+06
# CO    1.299452e+06
# SD    1.272387e+06
#           ...
# MN    1.177435e+06
# ME    1.167912e+06
# AR    1.157449e+06
# GA    1.152296e+06
# HI    1.145655e+06
# Name: Price, Length: 62, dtype: float64

# %%
df.groupby('State')['Price'].mean().sort_values(ascending=False).plot()
# Out:
# <AxesSubplot:xlabel='State'>

# %% [markdown]
# ### Answer : yes state does affect the price of house
#
# ###         While     housing   prices   tend to rise and fall on a national level, you may live in a micro-climate that
#
# ### defies the norm. Even when housing prices fall across the nation, prices in your neighborhood may rise.
#
# ### This  occurs due to desirability. If you live in an excellent school district or trendy area where people want to be, the
#
#
# ### price of houses in your area will likely go up. If a new manufacturing plant or large company brings jobs to
#
#
# ### your area, people may flock to the region, even if the population was small before. If new housing isn't built
#
#
# ### fast enough to accommodate the influx of people, housing pries in the area will rise. Even if the supply of
#
# ### housing does keep pace with the demand, your home's value may increase simply because people want to be
#
# ### where you are.

# %% [markdown]
# # Question : Does population of area affect price of house?

# %%
df['Area Population'].describe()
# Out:
# count     5000.000000
# mean     36163.516039
# std       9925.650114
# min        172.610686
# 25%      29403.928702
# 50%      36199.406689
# 75%      42861.290769
# max      69621.713378
# Name: Area Population, dtype: float64

# %%
ranges = [0, 10000, 20000, 30000, 40000, 50000, 60000, np.inf]
label = ['0-10k', '10k-20k', '20k-30k', '30k-40k', '40k-50k', '50k-60k', '60k+']

df['Population group'] = pd.cut(df['Area Population'], bins=ranges, labels=label)

# %%
sns.catplot(x='Population group', y='Price', kind='point', ci=None, data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Answer : Populated states clearly have expensive houses.

# %% [markdown]
# # Question :  Which factors affect the price of house the most?

# %%
x_col = ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Bedrooms', 'Avg. Area Number of Rooms', 'Area Population']
y_col = ['Price']

sns.pairplot(df, 
            x_vars= x_col,
            y_vars= y_col)
plt.show()

# %%
# Import LabelEncoder
from sklearn.preprocessing import LabelEncoder

# Instantiate LabelEncoder
le=LabelEncoder()

# Iterate over all the values of each column and extract their dtypes
for col in df.columns:
    # Compare if the dtype is object
    if df[col].dtypes=='object':
    # Use LabelEncoder to do the numeric transformation
        df[col]=le.fit_transform(df[col])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

X = df.drop(['Price', 'Population group', 'Address'], axis=1)
y = df['Price']

pipeline = Pipeline([
    ('std_scalar', StandardScaler())])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
print("Train score:")
print(lin_reg.score(X_train, y_train))

print("Test score:")
print(lin_reg.score(X_test, y_test))
# Out:
# Train score:
# 0.9192986579571021
# Test score:
# 0.9146818408057482

# %%
coeff_df = pd.DataFrame(lin_reg.coef_, X.columns, columns=['Coefficient'])
coeff_df.sort_values(by='Coefficient', ascending=False)
# Out:
#                                 Coefficient
# Avg. Area Income              232679.729575
# Avg. Area House Age           163840.999409
# Area Population               151252.336165
# Avg. Area Number of Rooms     121110.590639
# Avg. Area Number of Bedrooms    2892.813628
# State                              2.513886

# %%
names = df.drop(['Price', 'Population group', 'Address'], axis=1).columns
lr_coef = lin_reg.fit(X_train, y_train).coef_
_ = plt.plot(range(len(names)), lr_coef)
_ = plt.xticks(range(len(names)), names, rotation=90)
_ = plt.ylabel('Coefficients')
plt.show()

# %% [markdown]
# ### Answer : The model suggests that area income, house age and area population afftects "Price" of houses the most.

# %% [markdown]
# # Conclusion :

# %% [markdown]
# ## > The model suggests that area income, house age and area population afftects "Price" of houses the most.
#
#
# ## > Factors like city, number of rooms and bedrooms will also be a affecting factor for the price in residential houses.
#
#
# # > And other factors which are not in this dataset like economy, interest rate will also be important.

# %% [markdown]
# ![Screenshot%202022-05-07%20160907.png](attachment:Screenshot%202022-05-07%20160907.png)

# %% [markdown]
# ## I have added above image to  show the crime rates per states in US.Because if crime rates increases house values of taht area decreases.

# %% [markdown]
# ![region%20US%20House%20sales.png](attachment:region%20US%20House%20sales.png)

# %% [markdown]
# ## The above Image shows house sales by region in US as per 2021

# %% [markdown]
# ![Sales%20by%20price%20range%20in%20US.png](attachment:Sales%20by%20price%20range%20in%20US.png)

# %% [markdown]
# ## The above image shows the sales by price range in US as per 2021.We can clearly say that most of houses with having midrange price were  sold most in 2021.

# %% [markdown]
# ### Note : Till this I have covered many actors but,didn't talk about pandemic(covid-19).The whole world has sufferedfrom this and some of country are still fighting from it.Yes it impacts all the countrie,does not matter if country is developed country or progressive country.The pandemic affect on all the area including house pricing on which we are working on right now
#
# ### By purpsoe if we ignore the effects of pandemic from US for upcoming ten years,then at finally we can reach to conlcusion for which factor will affet house prices in upcoming ten years.

# %% [markdown]
# # CONCLUSION :

# %% [markdown]
# # (1) Population
#
#
# # (2) GDP
#
#
# # (3) Interest Rate
#
#
# # (4) Avg. Income of residents of the city house is located in.
#
#
# # (5) Avg Age of Houses in same city
#
#
# # (6) Avg Number of Rooms for Houses in same city
#
#
# # (7) Avg Number of Bedrooms for Houses in same city
#
#
# # (8) Crime Rate in Particular city(can effect more in upcoming years)
